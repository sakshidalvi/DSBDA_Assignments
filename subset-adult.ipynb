# %%
import pandas as pd
import numpy as np   
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('adult.csv')

# %%
df
# Out:
#        39          State-gov   77516    Bachelors  13        Never-married  \
# 0      50   Self-emp-not-inc   83311    Bachelors  13   Married-civ-spouse
# 1      38            Private  215646      HS-grad   9             Divorced
# 2      53            Private  234721         11th   7   Married-civ-spouse
# 3      28            Private  338409    Bachelors  13   Married-civ-spouse
# 4      37            Private  284582      Masters  14   Married-civ-spouse
# ...    ..                ...     ...          ...  ..                  ...
# 32555  27            Private  257302   Assoc-acdm  12   Married-civ-spouse
# 32556  40            Private  154374      HS-grad   9   Married-civ-spouse
# 32557  58            Private  151910      HS-grad   9              Widowed
# 32558  22            Private  201490      HS-grad   9        Never-married
# 32559  52       Self-emp-inc  287927      HS-grad   9   Married-civ-spouse
#
# ...

# %%
df.columns=['age','workclass','fnlwgt','education','education-num','marital-status'
           ,'occupation','relationship','race','sex','capital-gain','capital-loss','hours-per-week'
           ,'native-country','last_col']

# %%
df
# Out:
#        age          workclass  fnlwgt    education  education-num  \
# 0       50   Self-emp-not-inc   83311    Bachelors             13
# 1       38            Private  215646      HS-grad              9
# 2       53            Private  234721         11th              7
# 3       28            Private  338409    Bachelors             13
# 4       37            Private  284582      Masters             14
# ...    ...                ...     ...          ...            ...
# 32555   27            Private  257302   Assoc-acdm             12
# 32556   40            Private  154374      HS-grad              9
# 32557   58            Private  151910      HS-grad              9
# 32558   22            Private  201490      HS-grad              9
# 32559   52       Self-emp-inc  287927      HS-grad              9
#
#             marital-status          occupation    relationship    race  \
# 0       Married-civ-spouse     Exec-managerial         Husband   White
# ...

# %%
df.shape
# Out:
# (32560, 15)

# %%
df.dtypes
# Out:
# age                int64
# workclass         object
# fnlwgt             int64
# education         object
# education-num      int64
# marital-status    object
# occupation        object
# relationship      object
# race              object
# sex               object
# capital-gain       int64
# capital-loss       int64
# hours-per-week     int64
# native-country    object
# last_col          object
# dtype: object

# %%
df.isnull().sum()
# Out:
# age               0
# workclass         0
# fnlwgt            0
# education         0
# education-num     0
# marital-status    0
# occupation        0
# relationship      0
# race              0
# sex               0
# capital-gain      0
# capital-loss      0
# hours-per-week    0
# native-country    0
# last_col          0
# dtype: int64

# %%
df['relationship'].unique()
# Out:
# array([' Husband', ' Not-in-family', ' Wife', ' Own-child', ' Unmarried',
#        ' Other-relative'], dtype=object)

# %%
husband=df[df['relationship']==' Husband']
husband
# Out:
#        age          workclass  fnlwgt      education  education-num  \
# 0       50   Self-emp-not-inc   83311      Bachelors             13
# 2       53            Private  234721           11th              7
# 6       52   Self-emp-not-inc  209642        HS-grad              9
# 8       42            Private  159449      Bachelors             13
# 9       37            Private  280464   Some-college             10
# ...    ...                ...     ...            ...            ...
# 32549   43   Self-emp-not-inc   27242   Some-college             10
# 32550   32            Private   34066           10th              6
# 32551   43            Private   84661      Assoc-voc             11
# 32553   53            Private  321865        Masters             14
# 32556   40            Private  154374        HS-grad              9
#
#             marital-status          occupation relationship  \
# 0       Married-civ-spouse     Exec-managerial      Husband
# ...

# %%
sns.countplot(df["sex"]);
# Out:
# C:\Users\Manasi\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
wife=df[df['relationship']==' Wife']
wife
# Out:
#        age      workclass  fnlwgt      education  education-num  \
# 3       28        Private  338409      Bachelors             13
# 4       37        Private  284582        Masters             14
# 36      19        Private  544091        HS-grad              9
# 49      25        Private   32275   Some-college             10
# 51      47        Private   51835    Prof-school             15
# ...    ...            ...     ...            ...            ...
# 32527   31        Private  292592        HS-grad              9
# 32529   35              ?  320084      Bachelors             13
# 32544   39      Local-gov  111499     Assoc-acdm             12
# 32555   27        Private  257302     Assoc-acdm             12
# 32559   52   Self-emp-inc  287927        HS-grad              9
#
#             marital-status          occupation relationship    race      sex  \
# 3       Married-civ-spouse      Prof-specialty         Wife   Black   Female
# ...

# %%
unmarried=df[df['relationship']==' Unmarried']
unmarried.head()
# Out:
#     age          workclass  fnlwgt education  education-num  marital-status  \
# 16   32            Private  186824   HS-grad              9   Never-married
# 18   43   Self-emp-not-inc  292175   Masters             14        Divorced
# 20   54            Private  302146   HS-grad              9       Separated
# 23   59            Private  109015   HS-grad              9        Divorced
# 34   48            Private  242406      11th              7   Never-married
#
#             occupation relationship    race      sex  capital-gain  \
# 16   Machine-op-inspct    Unmarried   White     Male             0
# 18     Exec-managerial    Unmarried   White   Female             0
# 20       Other-service    Unmarried   Black   Female             0
# 23        Tech-support    Unmarried   White   Female             0
# 34   Machine-op-inspct    Unmarried   White     Male             0
#
#     capital-loss  hours-per-week  native-country last_col
# ...

# %%
df_merged=pd.merge(
    left= husband,
    right= wife,
    on='sex'
)

# %%
df_merged
# Out:
#        age_x        workclass_x  fnlwgt_x education_x  education-num_x  \
# 0         50   Self-emp-not-inc     83311   Bachelors               13
# 1         50   Self-emp-not-inc     83311   Bachelors               13
# 2         53            Private    234721        11th                7
# 3         53            Private    234721        11th                7
# 4         52   Self-emp-not-inc    209642     HS-grad                9
# ...      ...                ...       ...         ...              ...
# 27945     34            Private    175878     HS-grad                9
# 27946     34            Private    175878     HS-grad                9
# 27947     34            Private    175878     HS-grad                9
# 27948     34            Private    175878     HS-grad                9
# 27949     34            Private    175878     HS-grad                9
#
#           marital-status_x        occupation_x relationship_x  race_x  \
# ...

# %%
df_merged.shape
# Out:
# (27950, 29)

# %%
sort_age=df.sort_values(by='age')
sort_age
# Out:
#        age          workclass  fnlwgt      education  education-num  \
# 15541   17                  ?  112942           10th              6
# 26089   17   Self-emp-not-inc  174120           12th              8
# 22495   17            Private  118792           11th              7
# 22856   17          Local-gov  340043           12th              8
# 12980   17                  ?  262196           10th              6
# ...    ...                ...     ...            ...            ...
# 11511   90            Private   87285        HS-grad              9
# 12450   90                  ?  225063   Some-college             10
# 6623    90            Private  313986           11th              7
# 18831   90            Private  115306        Masters             14
# 8805    90            Private   87372    Prof-school             15
#
#             marital-status          occupation relationship  \
# 15541        Never-married                   ?    Own-child
# ...

# %%
df1=df.transpose()
df1
# Out:
#                               0                   1                    2      \
# age                              50                  38                   53
# workclass          Self-emp-not-inc             Private              Private
# fnlwgt                        83311              215646               234721
# education                 Bachelors             HS-grad                 11th
# education-num                    13                   9                    7
# marital-status   Married-civ-spouse            Divorced   Married-civ-spouse
# occupation          Exec-managerial   Handlers-cleaners    Handlers-cleaners
# relationship                Husband       Not-in-family              Husband
# race                          White               White                Black
# sex                            Male                Male                 Male
# capital-gain                      0                   0                    0
# ...

# %%
#Melting the data on the value variables as type and category
melt_result = pd.melt(
    frame = df,
    id_vars = 'fnlwgt',
    value_vars=['occupation','education']
)

# %%
melt_result
# Out:
#        fnlwgt    variable               value
# 0       83311  occupation     Exec-managerial
# 1      215646  occupation   Handlers-cleaners
# 2      234721  occupation   Handlers-cleaners
# 3      338409  occupation      Prof-specialty
# 4      284582  occupation     Exec-managerial
# ...       ...         ...                 ...
# 65115  257302   education          Assoc-acdm
# 65116  154374   education             HS-grad
# 65117  151910   education             HS-grad
# 65118  201490   education             HS-grad
# 65119  287927   education             HS-grad
#
# [65120 rows x 3 columns]

# %%
melt_result.pivot_table(index = 'fnlwgt', columns = 'variable', values = 'value', \
               aggfunc = 'sum', fill_value = 0)
# Out:
# variable      education          occupation
# fnlwgt
# 12285      Some-college                   ?
# 13769      Some-college   Machine-op-inspct
# 14878       Prof-school      Prof-specialty
# 18827      Some-college    Transport-moving
# 19214           HS-grad   Handlers-cleaners
# ...                 ...                 ...
# 1226583       Bachelors               Sales
# 1268339         HS-grad        Tech-support
# 1366120       Assoc-voc       Other-service
# 1455435      Assoc-acdm        Craft-repair
# 1484705    Some-college     Exec-managerial
#
# [21647 rows x 2 columns]
