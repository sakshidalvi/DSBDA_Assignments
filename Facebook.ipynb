# %% [markdown]
# Perform the following operations using Python on the Facebook metrics data sets
#
# a. Create data subsets for type of post
#
# b. Merge two subsets
#
# c. Sort Data on Page total likes
#
# d. Transposing Data
#
# e. Melting Data to long format
#
# f. Casting data to wide format

# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("F:\DSBDALExam DataSets\DSBDALExam DataSets\dataset_Facebook.csv", ";")
data
# Out:
#      Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0              139441   Photo         2          12             4          3
# 1              139441  Status         2          12             3         10
# 2              139441   Photo         3          12             3          3
# 3              139441   Photo         2          12             2         10
# 4              139441   Photo         2          12             2          3
# ..                ...     ...       ...         ...           ...        ...
# 495             85093   Photo         3           1             7          2
# 496             81370   Photo         2           1             5          8
# 497             81370   Photo         1           1             5          2
# 498             81370   Photo         3           1             4         11
# 499             81370   Photo         2           1             4          4
#
# ...

# %%
data.columns
# Out:
# Index(['Page total likes', 'Type', 'Category', 'Post Month', 'Post Weekday',
#        'Post Hour', 'Paid', 'Lifetime Post Total Reach',
#        'Lifetime Post Total Impressions', 'Lifetime Engaged Users',
#        'Lifetime Post Consumers', 'Lifetime Post Consumptions',
#        'Lifetime Post Impressions by people who have liked your Page',
#        'Lifetime Post reach by people who like your Page',
#        'Lifetime People who have liked your Page and engaged with your post',
#        'comment', 'like', 'share', 'Total Interactions'],
#       dtype='object')

# %%
post_type = data['Type'].value_counts()

# %%
post_type
# Out:
# Photo     426
# Status     45
# Link       22
# Video       7
# Name: Type, dtype: int64

# %%
# 1. Create data subsets for type of post

photo = data[data["Type"] == 'Photo']
status = data[data["Type"] == 'Status']
link = data[data["Type"] == 'Link']
video = data[data["Type"] == 'Video']

# %%
# 2. Merge two subsets

merged = pd.concat([photo, status])

# %%
merged.shape
# Out:
# (471, 19)

# %%
# 3. Sort data on total page likes

data.sort_values(by="Page total likes")
# Out:
#      Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 499             81370   Photo         2           1             4          4
# 496             81370   Photo         2           1             5          8
# 498             81370   Photo         3           1             4         11
# 497             81370   Photo         1           1             5          2
# 493             85093   Photo         3           1             1          2
# ..                ...     ...       ...         ...           ...        ...
# 10             139441  Status         2          12             5         10
# 11             139441   Photo         2          12             5         10
# 13             139441   Photo         2          12             5          3
# 7              139441   Photo         3          12             7          9
# 0              139441   Photo         2          12             4          3
#
# ...

# %%
# 4. Transposing dataframe

data.transpose()
# Out:
#                                                        0       1       2    \
# Page total likes                                    139441  139441  139441
# Type                                                 Photo  Status   Photo
# Category                                                 2       2       3
# Post Month                                              12      12      12
# Post Weekday                                             4       3       3
# Post Hour                                                3      10       3
# Paid                                                   0.0     0.0     0.0
# Lifetime Post Total Reach                             2752   10460    2413
# Lifetime Post Total Impressions                       5091   19057    4373
# Lifetime Engaged Users                                 178    1457     177
# Lifetime Post Consumers                                109    1361     113
# ...

# %%
# 5. Melting dataset into long format

melt_data = data[["Page total likes", "Type", "Category"]]

# %%
melt_data
# Out:
#      Page total likes    Type  Category
# 0              139441   Photo         2
# 1              139441  Status         2
# 2              139441   Photo         3
# 3              139441   Photo         2
# 4              139441   Photo         2
# ..                ...     ...       ...
# 495             85093   Photo         3
# 496             81370   Photo         2
# 497             81370   Photo         1
# 498             81370   Photo         3
# 499             81370   Photo         2
#
# [500 rows x 3 columns]

# %%
pd.melt(melt_data, id_vars=["Type", "Category"])
# Out:
#        Type  Category          variable   value
# 0     Photo         2  Page total likes  139441
# 1    Status         2  Page total likes  139441
# 2     Photo         3  Page total likes  139441
# 3     Photo         2  Page total likes  139441
# 4     Photo         2  Page total likes  139441
# ..      ...       ...               ...     ...
# 495   Photo         3  Page total likes   85093
# 496   Photo         2  Page total likes   81370
# 497   Photo         1  Page total likes   81370
# 498   Photo         3  Page total likes   81370
# 499   Photo         2  Page total likes   81370
#
# [500 rows x 4 columns]

# %%
# 6. Casting data into wide format

new_data = melt_data.drop_duplicates()
new_data
# Out:
#      Page total likes    Type  Category
# 0              139441   Photo         2
# 1              139441  Status         2
# 2              139441   Photo         3
# 14             138414   Photo         2
# 15             138414  Status         2
# ..                ...     ...       ...
# 492             85979    Link         1
# 493             85093   Photo         3
# 496             81370   Photo         2
# 497             81370   Photo         1
# 498             81370   Photo         3
#
# [227 rows x 3 columns]

# %%
data_new = new_data.sort_values(by="Page total likes")

# %%
data_new
# Out:
#      Page total likes    Type  Category
# 498             81370   Photo         3
# 497             81370   Photo         1
# 496             81370   Photo         2
# 493             85093   Photo         3
# 486             85979   Photo         3
# ..                ...     ...       ...
# 41             138895    Link         1
# 28             138895   Photo         2
# 2              139441   Photo         3
# 1              139441  Status         2
# 0              139441   Photo         2
#
# [227 rows x 3 columns]
