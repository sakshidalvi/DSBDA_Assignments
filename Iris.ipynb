# %% [markdown]
# Perform the following operations using Python on the Iris data sets
#
# g. Create data subsets for different species
#
# h. Merge two subsets
#
# i. Sort Data Petal Length
#
# j. Transposing Data
#
# k. Melting Data to long format
#
# l. Casting data to wide format

# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("F:\DSBDALExam DataSets\DSBDALExam DataSets\Iris\Iris.csv")
data
# Out:
#      sepal length in cm  sepal width in cm  petal length in cm  \
# 0                   5.1                3.5                 1.4
# 1                   4.9                3.0                 1.4
# 2                   4.7                3.2                 1.3
# 3                   4.6                3.1                 1.5
# 4                   5.0                3.6                 1.4
# ..                  ...                ...                 ...
# 145                 6.7                3.0                 5.2
# 146                 6.3                2.5                 5.0
# 147                 6.5                3.0                 5.2
# 148                 6.2                3.4                 5.4
# 149                 5.9                3.0                 5.1
#
#      petal width in cm           class
# 0                  0.2     Iris-setosa
# 1                  0.2     Iris-setosa
# 2                  0.2     Iris-setosa
# 3                  0.2     Iris-setosa
# ...

# %%
# 1. Create data subsetd for different species

setosa = data[data['class'] == 'Iris-setosa']
versicolor = data[data['class'] == 'Iris-versicolor']
virginica = data[data['class'] == 'Iris-virginica']

# %%
# 2. Merge two subsets

pd.concat([setosa, virginica])
# Out:
#      sepal length in cm  sepal width in cm  petal length in cm  \
# 0                   5.1                3.5                 1.4
# 1                   4.9                3.0                 1.4
# 2                   4.7                3.2                 1.3
# 3                   4.6                3.1                 1.5
# 4                   5.0                3.6                 1.4
# ..                  ...                ...                 ...
# 145                 6.7                3.0                 5.2
# 146                 6.3                2.5                 5.0
# 147                 6.5                3.0                 5.2
# 148                 6.2                3.4                 5.4
# 149                 5.9                3.0                 5.1
#
#      petal width in cm           class
# 0                  0.2     Iris-setosa
# 1                  0.2     Iris-setosa
# 2                  0.2     Iris-setosa
# 3                  0.2     Iris-setosa
# ...

# %%
# 3. Sort data by petal length

data.sort_values(by = "petal length in cm")
# Out:
#      sepal length in cm  sepal width in cm  petal length in cm  \
# 22                  4.6                3.6                 1.0
# 13                  4.3                3.0                 1.1
# 14                  5.8                4.0                 1.2
# 35                  5.0                3.2                 1.2
# 36                  5.5                3.5                 1.3
# ..                  ...                ...                 ...
# 131                 7.9                3.8                 6.4
# 105                 7.6                3.0                 6.6
# 117                 7.7                3.8                 6.7
# 122                 7.7                2.8                 6.7
# 118                 7.7                2.6                 6.9
#
#      petal width in cm           class
# 22                 0.2     Iris-setosa
# 13                 0.1     Iris-setosa
# 14                 0.2     Iris-setosa
# 35                 0.2     Iris-setosa
# ...

# %%
# 4. Transposing data

data.transpose()
# Out:
#                             0            1            2            3    \
# sepal length in cm          5.1          4.9          4.7          4.6
# sepal width in cm           3.5          3.0          3.2          3.1
# petal length in cm          1.4          1.4          1.3          1.5
# petal width in cm           0.2          0.2          0.2          0.2
# class               Iris-setosa  Iris-setosa  Iris-setosa  Iris-setosa
#
#                             4            5            6            7    \
# sepal length in cm          5.0          5.4          4.6          5.0
# sepal width in cm           3.6          3.9          3.4          3.4
# petal length in cm          1.4          1.7          1.4          1.5
# petal width in cm           0.2          0.4          0.3          0.2
# class               Iris-setosa  Iris-setosa  Iris-setosa  Iris-setosa
#
#                             8            9    ...             140  \
# ...

# %%
# 5. Melting to long format

pd.melt(data, id_vars=["class"])
# Out:
#               class            variable  value
# 0       Iris-setosa  sepal length in cm    5.1
# 1       Iris-setosa  sepal length in cm    4.9
# 2       Iris-setosa  sepal length in cm    4.7
# 3       Iris-setosa  sepal length in cm    4.6
# 4       Iris-setosa  sepal length in cm    5.0
# ..              ...                 ...    ...
# 595  Iris-virginica   petal width in cm    2.3
# 596  Iris-virginica   petal width in cm    1.9
# 597  Iris-virginica   petal width in cm    2.0
# 598  Iris-virginica   petal width in cm    2.3
# 599  Iris-virginica   petal width in cm    1.8
#
# [600 rows x 3 columns]
