# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('/content/movies_metadata.csv', on_bad_lines='skip')
df.head()
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2882: DtypeWarning: Columns (10) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#    adult                              belongs_to_collection    budget  \
# 0  False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1  False                                                NaN  65000000
# 2  False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3  False                                                NaN  16000000
# 4  False  {'id': 96871, 'name': 'Father of the Bride Col...         0
#
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# ...

# %%
df.tail()
# Out:
#        adult belongs_to_collection budget  \
# 45461  False                   NaN      0
# 45462  False                   NaN      0
# 45463  False                   NaN      0
# 45464  False                   NaN      0
# 45465  False                   NaN      0
#
#                                                   genres  \
# 45461  [{'id': 18, 'name': 'Drama'}, {'id': 10751, 'n...
# 45462                      [{'id': 18, 'name': 'Drama'}]
# 45463  [{'id': 28, 'name': 'Action'}, {'id': 18, 'nam...
# 45464                                                 []
# 45465                                                 []
#
#                                    homepage      id    imdb_id  \
# 45461  http://www.imdb.com/title/tt6209470/  439050  tt6209470
# 45462                                   NaN  111109  tt2028550
# 45463                                   NaN   67758  tt0303758
# 45464                                   NaN  227506  tt0008536
# ...

# %%
df.shape
# Out:
# (45466, 24)

# %%
df.dtypes
# Out:
# adult                     object
# belongs_to_collection     object
# budget                    object
# genres                    object
# homepage                  object
# id                        object
# imdb_id                   object
# original_language         object
# original_title            object
# overview                  object
# popularity                object
# poster_path               object
# production_companies      object
# production_countries      object
# release_date              object
# revenue                  float64
# runtime                  float64
# spoken_languages          object
# status                    object
# tagline                   object
# title                     object
# video                     object
# vote_average             float64
# vote_count               float64
# dtype: object

# %%
df.isnull()
# Out:
#        adult  belongs_to_collection  budget  genres  homepage     id  imdb_id  \
# 0      False                  False   False   False     False  False    False
# 1      False                   True   False   False      True  False    False
# 2      False                  False   False   False      True  False    False
# 3      False                   True   False   False      True  False    False
# 4      False                  False   False   False      True  False    False
# ...      ...                    ...     ...     ...       ...    ...      ...
# 45461  False                   True   False   False     False  False    False
# 45462  False                   True   False   False      True  False    False
# 45463  False                   True   False   False      True  False    False
# 45464  False                   True   False   False      True  False    False
# 45465  False                   True   False   False      True  False    False
#
# ...

# %%
#sumation of null values
df.isnull().sum()
# Out:
# adult                        0
# belongs_to_collection    40972
# budget                       0
# genres                       0
# homepage                 37684
# id                           0
# imdb_id                     17
# original_language           11
# original_title               0
# overview                   954
# popularity                   5
# poster_path                386
# production_companies         3
# production_countries         3
# release_date                87
# revenue                      6
# runtime                    263
# spoken_languages             6
# status                      87
# tagline                  25054
# title                        6
# video                        6
# vote_average                 6
# vote_count                   6
# dtype: int64

# %%
df.fillna(method='ffill',inplace=True)

# %%
#testing data for null values
df.isnull().sum()
# Out:
# adult                    0
# belongs_to_collection    0
# budget                   0
# genres                   0
# homepage                 0
# id                       0
# imdb_id                  0
# original_language        0
# original_title           0
# overview                 0
# popularity               0
# poster_path              0
# production_companies     0
# production_countries     0
# release_date             0
# revenue                  0
# runtime                  0
# spoken_languages         0
# status                   0
# tagline                  1
# title                    0
# video                    0
# vote_average             0
# vote_count               0
# dtype: int64

# %%
df.head()
# Out:
#    adult                              belongs_to_collection    budget  \
# 0  False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1  False  {'id': 10194, 'name': 'Toy Story Collection', ...  65000000
# 2  False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3  False  {'id': 119050, 'name': 'Grumpy Old Men Collect...  16000000
# 4  False  {'id': 96871, 'name': 'Father of the Bride Col...         0
#
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4                     [{'id': 35, 'name': 'Comedy'}]
#
#                                homepage     id    imdb_id original_language  \
# 0  http://toystory.disney.com/toy-story    862  tt0114709                en
# ...

# %%
eng = df[df['original_language']=="en"]
eng.head()
# Out:
#    adult                              belongs_to_collection    budget  \
# 0  False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1  False  {'id': 10194, 'name': 'Toy Story Collection', ...  65000000
# 2  False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3  False  {'id': 119050, 'name': 'Grumpy Old Men Collect...  16000000
# 4  False  {'id': 96871, 'name': 'Father of the Bride Col...         0
#
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4                     [{'id': 35, 'name': 'Comedy'}]
#
#                                homepage     id    imdb_id original_language  \
# 0  http://toystory.disney.com/toy-story    862  tt0114709                en
# ...

# %%
french = df[df['original_language']=="fr"]
french.head()
# Out:
#     adult                              belongs_to_collection    budget  \
# 28  False  {'id': 91698, 'name': 'Chili Palmer Collection...  18000000
# 32  False  {'id': 91698, 'name': 'Chili Palmer Collection...         0
# 58  False  {'id': 136214, 'name': 'Pocahontas Collection'...         0
# 67  False  {'id': 124935, 'name': 'The Lawnmower Man Coll...         0
# 72  False  {'id': 10924, 'name': 'From Dusk Till Dawn Col...         0
#
#                                                genres  \
# 28  [{'id': 14, 'name': 'Fantasy'}, {'id': 878, 'n...
# 32  [{'id': 10749, 'name': 'Romance'}, {'id': 12, ...
# 58  [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...
# 67  [{'id': 35, 'name': 'Comedy'}, {'id': 10749, '...
# 72  [{'id': 18, 'name': 'Drama'}, {'id': 36, 'name...
#
#                                              homepage     id    imdb_id  \
# 28  http://www.mgm.com/title_title.do?title_star=L...    902  tt0112682
# ...

# %%
zh = df[df['original_language']=="zh"]
zh.head()
# Out:
#      adult                              belongs_to_collection  budget  \
# 29   False  {'id': 91698, 'name': 'Chili Palmer Collection...       0
# 228  False  {'id': 96665, 'name': 'Dumb and Dumber Collect...       0
# 294  False  {'id': 48188, 'name': 'Poison Ivy Collection',...  400000
# 305  False  {'id': 131, 'name': 'Three Colors Collection',...       0
# 321  False  {'id': 53159, 'name': 'The Santa Clause Collec...       0
#
#                                                 genres  \
# 29   [{'id': 18, 'name': 'Drama'}, {'id': 80, 'name...
# 228  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 294  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 305                      [{'id': 18, 'name': 'Drama'}]
# 321  [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...
#
#                                               homepage      id    imdb_id  \
# 29   http://www.mgm.com/title_title.do?title_star=L...   37557  tt0115012
# ...

# %%
italian = df[df['original_language']=="it"]
italian.head()
# Out:
#      adult                              belongs_to_collection budget  \
# 52   False  {'id': 136214, 'name': 'Pocahontas Collection'...      0
# 57   False  {'id': 136214, 'name': 'Pocahontas Collection'...      0
# 122  False  {'id': 256377, 'name': 'The Muppet Collection'...      0
# 129  False  {'id': 91430, 'name': 'The Neverending Story C...      0
# 224  False  {'id': 182813, 'name': 'Clerks Collection', 'p...      0
#
#                                                 genres  \
# 52   [{'id': 18, 'name': 'Drama'}, {'id': 10769, 'n...
# 57   [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 122  [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...
# 129  [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...
# 224  [{'id': 80, 'name': 'Crime'}, {'id': 35, 'name...
#
#                                               homepage     id    imdb_id  \
# 52   http://www.mgm.com/#/our-titles/2083/The-Usual...  49133  tt0110299
# ...

# %%
#merging two subsets
df_merged = pd.merge(
    left = italian,
    right = french,
    on = "budget"
)
df_merged.head()
# Out:
#   adult_x                            belongs_to_collection_x budget  \
# 0   False  {'id': 136214, 'name': 'Pocahontas Collection'...      0
# 1   False  {'id': 136214, 'name': 'Pocahontas Collection'...      0
# 2   False  {'id': 136214, 'name': 'Pocahontas Collection'...      0
# 3   False  {'id': 136214, 'name': 'Pocahontas Collection'...      0
# 4   False  {'id': 136214, 'name': 'Pocahontas Collection'...      0
#
#                                             genres_x  \
# 0  [{'id': 18, 'name': 'Drama'}, {'id': 10769, 'n...
# 1  [{'id': 18, 'name': 'Drama'}, {'id': 10769, 'n...
# 2  [{'id': 18, 'name': 'Drama'}, {'id': 10769, 'n...
# 3  [{'id': 18, 'name': 'Drama'}, {'id': 10769, 'n...
# 4  [{'id': 18, 'name': 'Drama'}, {'id': 10769, 'n...
#
#                                           homepage_x   id_x  imdb_id_x  \
# 0  http://www.mgm.com/#/our-titles/2083/The-Usual...  49133  tt0110299
# 1  http://www.mgm.com/#/our-titles/2083/The-Usual...  49133  tt0110299
# ...

# %%
df_merged.shape
# Out:
# (3181401, 47)

# %%
#sorting the data 
sort_share=df.sort_values(by="vote_count")
sort_share.head()
# Out:
#        adult                              belongs_to_collection budget  \
# 45465  False  {'id': 200641, 'name': 'Red Lotus Collection',...      0
# 37998  False  {'id': 385250, 'name': 'Black Magic Collection...      0
# 37981  False  {'id': 33381, 'name': 'The Whistler collection...      0
# 37971  False  {'id': 33381, 'name': 'The Whistler collection...      0
# 37968  False  {'id': 33381, 'name': 'The Whistler collection...      0
#
#                                                   genres  \
# 45465                                                 []
# 37998  [{'id': 10749, 'name': 'Romance'}, {'id': 18, ...
# 37981  [{'id': 18, 'name': 'Drama'}, {'id': 35, 'name...
# 37971                     [{'id': 28, 'name': 'Action'}]
# 37968                      [{'id': 18, 'name': 'Drama'}]
#
#                                              homepage      id    imdb_id  \
# 45465            http://www.imdb.com/title/tt6209470/  461257  tt6980792
# ...

# %%
#transposing dataset
transposed_french=french.transpose()
transposed_french.head()
# Out:
#                                                                    28     \
# adult                                                              False
# belongs_to_collection  {'id': 91698, 'name': 'Chili Palmer Collection...
# budget                                                          18000000
# genres                 [{'id': 14, 'name': 'Fantasy'}, {'id': 878, 'n...
# homepage               http://www.mgm.com/title_title.do?title_star=L...
#
#                                                                    32     \
# adult                                                              False
# belongs_to_collection  {'id': 91698, 'name': 'Chili Palmer Collection...
# budget                                                                 0
# genres                 [{'id': 10749, 'name': 'Romance'}, {'id': 12, ...
# homepage               http://www.mgm.com/title_title.do?title_star=L...
#
#                                                                    58     \
# ...

# %%
transposed_eng=eng.transpose()
transposed_eng.head()
# Out:
#                                                                    0      \
# adult                                                              False
# belongs_to_collection  {'id': 10194, 'name': 'Toy Story Collection', ...
# budget                                                          30000000
# genres                 [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# homepage                            http://toystory.disney.com/toy-story
#
#                                                                    1      \
# adult                                                              False
# belongs_to_collection  {'id': 10194, 'name': 'Toy Story Collection', ...
# budget                                                          65000000
# genres                 [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# homepage                            http://toystory.disney.com/toy-story
#
#                                                                    2      \
# ...

# %%
#Melting the data on the value variables 
# melt_result = pd.melt(
#     frame = df,
#     id_vars = "runtime",
#     value_vars = ['id','imdb_id']
# )
melt_result=pd.melt(df,id_vars = 'original_title', value_vars = ['imdb_id','original_language'])
melt_result
# Out:
#                     original_title           variable      value
# 0                        Toy Story            imdb_id  tt0114709
# 1                          Jumanji            imdb_id  tt0113497
# 2                 Grumpier Old Men            imdb_id  tt0113228
# 3                Waiting to Exhale            imdb_id  tt0114885
# 4      Father of the Bride Part II            imdb_id  tt0113041
# ...                            ...                ...        ...
# 90927                      رگ خواب  original_language         fa
# 90928          Siglo ng Pagluluwal  original_language         tl
# 90929                     Betrayal  original_language         en
# 90930          Satana likuyushchiy  original_language         en
# 90931                     Queerama  original_language         en
#
# [90932 rows x 3 columns]

# %%
melt_result.pivot_table(index = 'original_title', columns = 'variable', values = 'value', \
               aggfunc = 'sum', fill_value = 0)
# Out:
# variable                 imdb_id original_language
# original_title
# !Women Art Revolution  tt1699720                en
# #1 Cheerleader Camp    tt1637976                en
# #Horror                tt3526286                de
# #Pellichoopulu         tt5824826                te
# #SELFIEPARTY           tt5335198                uk
# ...                          ...               ...
# １リットルの涙                tt0494724                ja
# １３号待避線より　その護送車を狙え      tt0054325                ja
# ２０世紀少年< 第1章> 終わりの始まり   tt1155705                ja
# ３－４Ｘ１０月                tt0098967                ja
# ＳＭガールズ セイバーマリオネットＲ     tt3422000                ja
#
# [43373 rows x 2 columns]
