# %% [markdown]
# Perform the following operations using Python on census bureau databset(Adult data sets).
#
# s. Create data subsets for different Country, Sex, race.
#
# t. Merge two subsets
#
# u. Sort Data using customer ratings.
#
# v. Transposing Data
#
# w. Melting Data to long format
#
# x. Casting data to wide format

# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("F:\DSBDALExam DataSets\DSBDALExam DataSets\Adult\ADULT_DATA.csv")
data
# Out:
#        age          workclass  fnlwgt    education  education-num  \
# 0       39          State-gov   77516    Bachelors             13
# 1       50   Self-emp-not-inc   83311    Bachelors             13
# 2       38            Private  215646      HS-grad              9
# 3       53            Private  234721         11th              7
# 4       28            Private  338409    Bachelors             13
# ...    ...                ...     ...          ...            ...
# 32556   27            Private  257302   Assoc-acdm             12
# 32557   40            Private  154374      HS-grad              9
# 32558   58            Private  151910      HS-grad              9
# 32559   22            Private  201490      HS-grad              9
# 32560   52       Self-emp-inc  287927      HS-grad              9
#
#             marital-status          occupation    relationship    race  \
# 0            Never-married        Adm-clerical   Not-in-family   White
# ...

# %%
# 1. Subsets of country, sex, race

# country

countries = list(data['native-country'].unique())

# %%
data['native-country'].value_counts()
# Out:
#  United-States                 29170
#  Mexico                          643
#  ?                               583
#  Philippines                     198
#  Germany                         137
#  Canada                          121
#  Puerto-Rico                     114
#  El-Salvador                     106
#  India                           100
#  Cuba                             95
#  England                          90
#  Jamaica                          81
#  South                            80
#  China                            75
#  Italy                            73
#  Dominican-Republic               70
#  Vietnam                          67
#  Guatemala                        64
#  Japan                            62
#  Poland                           60
#  Columbia                         59
#  Taiwan                           51
#  Haiti                            44
#  Iran                             43
#  Portugal                         37
# ...

# %%
subsets = []

for i in range(len(countries)):
    temp = data[data['native-country'] == countries[i]]
    subsets.append(temp)

# %%
subsets[1]
# Out:
#        age          workclass  fnlwgt   education  education-num  \
# 4       28            Private  338409   Bachelors             13
# 81      52            Private  276515   Bachelors             13
# 638     47       Self-emp-inc  248145     5th-6th              3
# 701     31            Private  243605   Bachelors             13
# 1237    41   Self-emp-not-inc  209344     HS-grad              9
# ...    ...                ...     ...         ...            ...
# 30841   37            Private  238433     1st-4th              2
# 30892   52            Private  222646        12th              8
# 30906   39   Self-emp-not-inc  251323         9th              5
# 31149   52       Self-emp-inc  230767   Bachelors             13
# 31907   48            Private  379883     Masters             14
#
#             marital-status          occupation     relationship    race  \
# 4       Married-civ-spouse      Prof-specialty             Wife   Black
# ...

# %%
# sex

data['sex'].value_counts()
# Out:
#  Male      21790
#  Female    10771
# Name: sex, dtype: int64

# %%
from sklearn import preprocessing

# %%
le = preprocessing.LabelEncoder()

data['sex'] = le.fit_transform(data['sex'])

# %%
data['sex']
# Out:
# 0        1
# 1        1
# 2        1
# 3        1
# 4        0
#         ..
# 32556    0
# 32557    1
# 32558    0
# 32559    1
# 32560    0
# Name: sex, Length: 32561, dtype: int32

# %%
male = data[data['sex'] == 1]

# %%
female = data[data['sex'] == 0]

# %%
# race

data['race'].value_counts()
# Out:
#  White                 27816
#  Black                  3124
#  Asian-Pac-Islander     1039
#  Amer-Indian-Eskimo      311
#  Other                   271
# Name: race, dtype: int64

# %%
white = data[data["race"].values == 'White']

# %%
white
# Out:
# Empty DataFrame
# Columns: [age, workclass, fnlwgt, education, education-num, marital-status, occupation, relationship, race, sex, capital-gain, capital-loss, hours-per-week, native-country, population]
# Index: []
